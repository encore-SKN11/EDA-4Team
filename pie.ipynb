# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, r2_score

# %%
# 📌 1. CSV 파일 로드
df = pd.read_csv('Ecommerce_Consumer_Behavior_Analysis_Data.csv')
lst = ['Purchase_Amount','Age', 'Gender', 'Income_Level', 'Marital_Status', 'Education_Level', 'Occupation', 'Purchase_Channel', 'Time_to_Decision']
df = df.loc[:, lst]
df
# Out:
#     Purchase_Amount  Age  Gender Income_Level Marital_Status Education_Level  \
# 0          $333.80    22  Female       Middle        Married      Bachelor's
# 1          $222.22    49    Male         High        Married     High School
# 2          $426.22    24  Female       Middle         Single        Master's
# 3          $101.31    29  Female       Middle         Single        Master's
# 4          $211.70    33  Female       Middle        Widowed     High School
# ..              ...  ...     ...          ...            ...             ...
# 995        $463.67    44  Female         High       Divorced      Bachelor's
# 996         $69.78    50  Female         High         Single     High School
# 997        $453.37    26    Male         High        Married      Bachelor's
# 998        $106.15    21  Female         High        Widowed      Bachelor's
# 999        $378.47    21  Female       Middle         Single     High School
#
#     Occupation Purchase_Channel  Time_to_Decision
# 0       Middle            Mixed                 2
# 1         High         In-Store                 6
# 2         High            Mixed                 3
# 3       Middle            Mixed                10
# 4       Middle            Mixed                 4
# ..         ...              ...               ...
# 995       High           Online                 5
# 996     Middle            Mixed                 9
# 997       High            Mixed                 9
# 998     Middle         In-Store                 8
# 999       High           Online                 2
#
# [1000 rows x 9 columns]

# %%
bins = [0, 19, 29, 39, 49, 59, 100]  # 나이대 구분을 위한 구간 설정
labels = ['10대', '20대', '30대', '40대', '50대', '60대 이상']  # 나이대 이름

# 'Age_Group' 컬럼을 추가하여 나이대별로 분류
df['Age_Group'] = pd.cut(df['Age'], bins=bins, labels=labels, right=True)

# 나이대별 인원 수 계산
age_group_counts = df['Age_Group'].value_counts()
age_group_counts
# Out:
# Age_Group
# 20대       308
# 40대       307
# 30대       299
# 10대        52
# 50대        34
# 60대 이상      0
# Name: count, dtype: int64
